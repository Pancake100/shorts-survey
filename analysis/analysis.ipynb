# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("videos.csv")
df.head()
# Out:
#                                                title    topic  \
# 0               This powder changes color like magic  science
# 1                           What if Time isn't real?  science
# 2  Part 1: Earth Has Been Falling for 4.6 Billion...  science
# 3          Today we look at some sound wave physics!  science
# 4  Scientists discovery breaks a fundamental rule...  science
#
#                                 url publish_date    likes  comments  shares  \
# 0  https://vt.tiktok.com/ZSxExR68v/    2022/4/19  4547000     27000  192000
# 1  https://vt.tiktok.com/ZSxExMr85/     2026/5/2   580000      2738   59000
# 2  https://vt.tiktok.com/ZSxExFVd4/    2026/2/28   472000      5395   24000
# 3  https://vt.tiktok.com/ZSxExj6M5/    2023/5/16  1086000      5562   44000
# 4  https://vt.tiktok.com/ZSxExFNAr/    2026/4/21   164000       939   24000
#
#    collections     views  subscribers group   id
# 0       196000  29177000     10546000   NaN  NaN
# ...

# %%
df['engagement_rate'] = (df['likes']+df['comments']+df['shares']+df['collections'])/df['views']
df.head()
# Out:
#                                                title    topic  \
# 0               This powder changes color like magic  science
# 1                           What if Time isn't real?  science
# 2  Part 1: Earth Has Been Falling for 4.6 Billion...  science
# 3          Today we look at some sound wave physics!  science
# 4  Scientists discovery breaks a fundamental rule...  science
#
#                                 url publish_date    likes  comments  shares  \
# 0  https://vt.tiktok.com/ZSxExR68v/    2022/4/19  4547000     27000  192000
# 1  https://vt.tiktok.com/ZSxExMr85/     2026/5/2   580000      2738   59000
# 2  https://vt.tiktok.com/ZSxExFVd4/    2026/2/28   472000      5395   24000
# 3  https://vt.tiktok.com/ZSxExj6M5/    2023/5/16  1086000      5562   44000
# 4  https://vt.tiktok.com/ZSxExFNAr/    2026/4/21   164000       939   24000
#
#    collections     views  subscribers group   id  engagement_rate
# 0       196000  29177000     10546000   NaN  NaN         0.170065
# ...

# %%
df["publish_date"] = pd.to_datetime(df["publish_date"])

# %%
collection_date = pd.to_datetime("2026-06-03")

df["age"] = (
    collection_date - df["publish_date"]
).dt.days

df["tp"] = df["views"] / np.log1p(df["age"]+1)

df.head()
# Out:
#                                                title    topic  \
# 0               This powder changes color like magic  science
# 1                           What if Time isn't real?  science
# 2  Part 1: Earth Has Been Falling for 4.6 Billion...  science
# 3          Today we look at some sound wave physics!  science
# 4  Scientists discovery breaks a fundamental rule...  science
#
#                                 url publish_date    likes  comments  shares  \
# 0  https://vt.tiktok.com/ZSxExR68v/   2022-04-19  4547000     27000  192000
# 1  https://vt.tiktok.com/ZSxExMr85/   2026-05-02   580000      2738   59000
# 2  https://vt.tiktok.com/ZSxExFVd4/   2026-02-28   472000      5395   24000
# 3  https://vt.tiktok.com/ZSxExj6M5/   2023-05-16  1086000      5562   44000
# 4  https://vt.tiktok.com/ZSxExFNAr/   2026-04-21   164000       939   24000
#
#    collections     views  subscribers group   id  engagement_rate   age  \
# ...

# %%
df['tp_rank'] = df['tp'].rank(ascending = False)
df['er_rank'] = df['engagement_rate'].rank(ascending = False)
df['avg_rank_score'] = (df['tp_rank']+df['er_rank'])/2 
df['avg_rank'] = df['avg_rank_score'].rank()

df.head()
# Out:
#                                                title    topic  \
# 0               This powder changes color like magic  science
# 1                           What if Time isn't real?  science
# 2  Part 1: Earth Has Been Falling for 4.6 Billion...  science
# 3          Today we look at some sound wave physics!  science
# 4  Scientists discovery breaks a fundamental rule...  science
#
#                                 url publish_date    likes  comments  shares  \
# 0  https://vt.tiktok.com/ZSxExR68v/   2022-04-19  4547000     27000  192000
# 1  https://vt.tiktok.com/ZSxExMr85/   2026-05-02   580000      2738   59000
# 2  https://vt.tiktok.com/ZSxExFVd4/   2026-02-28   472000      5395   24000
# 3  https://vt.tiktok.com/ZSxExj6M5/   2023-05-16  1086000      5562   44000
# 4  https://vt.tiktok.com/ZSxExFNAr/   2026-04-21   164000       939   24000
#
#    collections     views  subscribers group   id  engagement_rate   age  \
# ...

# %%
# Getting results info
# TODO the script for the ratings seems to id less files than there is 
ratings_df = pd.read_csv('participant_video_ratings.csv')
ratings_df.head()
# Out:
#               participant_id group  \
# 0  P-20260709T074312Z-5E8136     A
# 1  P-20260709T074312Z-5E8136     A
# 2  P-20260709T074312Z-5E8136     A
# 3  P-20260709T074312Z-5E8136     A
# 4  P-20260709T074312Z-5E8136     A
#
#                                        source_file video_id video_title  \
# 0  P-20260709T074312Z-5E8136_20260709T075918Z.json      S04   Video A10
# 1  P-20260709T074312Z-5E8136_20260709T075918Z.json      L01   Video A09
# 2  P-20260709T074312Z-5E8136_20260709T075918Z.json      S02   Video A07
# 3  P-20260709T074312Z-5E8136_20260709T075918Z.json      H03   Video A03
# 4  P-20260709T074312Z-5E8136_20260709T075918Z.json      H02   Video A02
#
#          video_topic  video_order_index  attractive_plain  clear_confusing  \
# 0            Science                  1                 0               -1
# 1  Language Learning                  2                -2               -3
# 2            Science                  3                -3               -3
# ...

# %%
ratings_df['group'].unique()
# Out:
# array(['A', 'B'], dtype=object)
